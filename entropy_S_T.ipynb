# %%
import shlex
from tqdm.notebook import tqdm
from IPython.display import display

import torch
import torch.nn as nn
import copy
from tqdm import tqdm_notebook
from torch.utils.data import ConcatDataset
from GTTA.data.good_loaders.fast_data_loader import InfiniteDataLoader, FastDataLoader
from GTTA.utils.register import register
import pandas as pd
import numpy as np

from GTTA import config_summoner
from GTTA.kernel.main import initialize_model_dataset
from GTTA.utils.args import args_parser
from GTTA.utils.load_manager import load_atta_algorithm, load_alg
from GTTA.utils.load_manager import load_tta_algorithm
from GTTA.utils.logger import load_logger

argv = shlex.split('--task train --config_path TTA_configs/PACS/base.yaml --gpu_idx 6 --exp_round 1')
print(argv)
args = args_parser(argv)
config = config_summoner(args)
load_logger(config)

alg = load_atta_algorithm(config)

D_S = alg.dataset[0]
D_T = alg.target_dataset
# Out:
# ['--task', 'train', '--config_path', 'TTA_configs/PACS/base.yaml', '--gpu_idx', '6', '--exp_round', '1']
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "config_path" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "test_ckpt" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "id_test_ckpt" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "full_clean" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "log_path" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tensorboard_logdir" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "train.num_steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "model.model_level" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "model.nonlinear_classifier" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "dataset.shift_type" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "dataset.domain" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "dataset.dataset_type" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "dataset.class_balanced" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "dataset.num_domains" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "tta" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.name" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.episodic" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "tta.SAR" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.SAR.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.SAR.reset_constant_em" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.SAR.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "tta.Tent" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.Tent.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.Tent.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "tta.TICP" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.num_drops" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.classifier_epochs" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.classifier_lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.num_gaussians" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.alpha" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.beta" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.test_interval" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.train_linear_classifier" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.temperature" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "tta.TICP.train_or_load" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.budgets" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.episodic" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "atta.SimATTA" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SimATTA.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SimATTA.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SimATTA.eh" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SimATTA.el" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SimATTA.cold_start" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "atta.Tent" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.Tent.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.Tent.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "atta.TAL" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.TAL.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.TAL.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.TAL.e0" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "atta.SAR" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SAR.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SAR.reset_constant_em" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.SAR.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:176: UserWarning: Missing argument "atta.EATA" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.EATA.steps" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.EATA.lr" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.EATA.d_margin" in the config file.
# /data/shurui.gui/Projects/TTA/GraphTTA/GTTA/utils/config_reader.py:172: UserWarning: Missing argument "atta.EATA.fisher_alpha" in the config file.
# This logger will substitute general print function
# Process Process-184:
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 318, in _bootstrap
#     util._exit_function()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
# KeyboardInterrupt
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/queues.py", line 195, in _finalize_join
#     thread.join()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# Unexpected exception formatting exception. Falling back to standard exception
# ERROR: 05/03/2023 11:28:06 AM - utils.py - line 87 : Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_557381/4046482833.py", line 1, in <module>
#     source_like_model = train_model_on(D_T, argent[:300], device, tol=1e-4, source_trained=True)
#   File "/tmp/ipykernel_557381/3662179842.py", line 30, in train_model_on
#     loss.backward()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/autograd/__init__.py", line 154, in backward
#     Variable._execution_engine.run_backward(
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ERROR: 05/03/2023 11:28:06 AM - utils.py - line 87 : Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 317, in executing
#     args = executing_cache[key]
# KeyError: (<code object backward at 0x7f82dc057660, file "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/_tensor.py", line 251>, 140200013821536, 52)
#
# During handling of the above exception, another exception occurred:
#
# ERROR: 05/03/2023 11:28:06 AM - utils.py - line 87 : Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1052, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 953, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1039, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 565, in stack_data
#     yield from collapse_repeated(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/utils.py", line 84, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 555, in mapper
#     return cls(f, options)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 520, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 369, in executing
#     args = find(source=cls.for_frame(frame), retry_cache=True)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 252, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 270, in for_filename
#     result = source_cache[filename] = cls._for_filename_and_lines(filename, lines)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 281, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 81, in __init__
#     self.asttokens()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 413, in asttokens
#     return ASTTokens(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/asttokens.py", line 59, in __init__
#     self._tokens = list(self._generate_tokens(source_text))
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/asttokens.py", line 85, in _generate_tokens
#     for index, tok in enumerate(tokenize.generate_tokens(io.StringIO(text).readline)):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/tokenize.py", line 525, in _tokenize
#     pseudomatch = _compile(PseudoToken).match(line, pos)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 878372) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1320, in _shutdown_workers
#     if w.is_alive():
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f8132600f70>
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#     self._shutdown_workers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1301, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# Process Process-258:
# Traceback (most recent call last):
# Process Process-259:
# Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 318, in _bootstrap
#     util._exit_function()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/process.py", line 318, in _bootstrap
#     util._exit_function()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/queues.py", line 195, in _finalize_join
#     thread.join()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/multiprocessing/queues.py", line 195, in _finalize_join
#     thread.join()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# Unexpected exception formatting exception. Falling back to standard exception
# ERROR: 05/03/2023 11:36:13 AM - utils.py - line 87 : Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_557381/4046482833.py", line 2, in <module>
#     target_like_model = train_model_on(D_T, np.random.choice(argent[-300:], 300, replace=False), device, tol=1e-4, source_trained=True)
#   File "/tmp/ipykernel_557381/390145985.py", line 32, in train_model_on
#     loss.backward()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/autograd/__init__.py", line 154, in backward
#     Variable._execution_engine.run_backward(
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ERROR: 05/03/2023 11:36:13 AM - utils.py - line 87 : Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 317, in executing
#     args = executing_cache[key]
# KeyError: (<code object backward at 0x7f82dc057660, file "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/_tensor.py", line 251>, 140200013821536, 52)
#
# During handling of the above exception, another exception occurred:
#
# ERROR: 05/03/2023 11:36:13 AM - utils.py - line 87 : Traceback (most recent call last):
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1052, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 953, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1039, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 565, in stack_data
#     yield from collapse_repeated(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/utils.py", line 84, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 555, in mapper
#     return cls(f, options)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 520, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 369, in executing
#     args = find(source=cls.for_frame(frame), retry_cache=True)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 252, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 270, in for_filename
#     result = source_cache[filename] = cls._for_filename_and_lines(filename, lines)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 281, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/stack_data/core.py", line 81, in __init__
#     self.asttokens()
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/executing/executing.py", line 413, in asttokens
#     return ASTTokens(
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/asttokens.py", line 65, in __init__
#     self.mark_tokens(self._tree)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/asttokens.py", line 76, in mark_tokens
#     MarkTokens(self).visit_tree(root_node)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/mark_tokens.py", line 49, in visit_tree
#     util.visit_tree(node, self._visit_before_children, self._visit_after_children)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/util.py", line 204, in visit_tree
#     ret = postvisit(current, par_value, value)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/mark_tokens.py", line 89, in _visit_after_children
#     first, last = self._expand_to_matching_pairs(first, last, node)
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/asttokens/mark_tokens.py", line 119, in _expand_to_matching_pairs
#     tok_info = tok[:2]
#   File "/data/shurui.gui/anaconda3/envs/torch_110/lib/python3.8/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 1218448) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.

# %% [markdown]
# ## Experiment 5: Whether high/low entropy corresponds to target/source domains?
#
# * Use target dataset.
# * Source-free AL setting, Source-trained model, m=500.
# * loss: distance between the sample and the true distribution
# * entropy: distance between the sample and the model distribution (source)

# %%
def softmax_entropy(x: torch.Tensor, y: torch.Tensor = None) -> torch.Tensor:
    """Entropy of softmax distribution from logits."""
    if y is None:
        if x.shape[1] == 1:
            x = torch.cat([x, -x], dim=1)
        return -(x.softmax(1) * x.log_softmax(1)).sum(1)
    else:
        return - 0.5 * (x.softmax(1) * y.log_softmax(1)).sum(1) - 0.5 * (y.softmax(1) * x.log_softmax(1)).sum(1)

# %%
Full_D_T_loader = FastDataLoader(D_T,  
                                 weights=None,
                                 batch_size=config.train.train_bs,
                                 num_workers=config.num_workers, 
                                 sequential=True)

entropy = np.array([], dtype=float)
loss = np.array([], dtype=float)
acc = np.array([], dtype=float)

device = config.device
model = copy.deepcopy(alg.model.cpu()).to(device)
model.eval()


with torch.no_grad():
    for data, target in tqdm(Full_D_T_loader):
        data, target = data.to(device), target.to(device)
        output = model(data)
        loss = np.concatenate([loss, config.metric.loss_func(output, target, reduction='none').cpu().numpy()])
        acc = np.concatenate([acc, (target == output.argmax(-1)).float().cpu().numpy()])
        entropy = np.concatenate([entropy, softmax_entropy(output).cpu().numpy()])
# Out:
#   0%|          | 0/497 [00:00<?, ?it/s]

# %%
argent = np.argsort(entropy)

# 

display(loss[argent[-300:]].mean())
display(loss[entropy < 1e-6].mean())
display(acc[argent[-300:]].mean())
display(acc[entropy < 1e-2].mean())
display(entropy[argent[-2000:]].min())
display(entropy[argent[:500]].max())
(entropy > 0.1).sum()

display(loss[np.random.choice(argent[-300:], 300, replace=False)].mean())
# Out:
# 1.9378976572553317
# 0.07726989215865558
# 0.23666666666666666
# 0.9407971864009379
# 0.45667752623558044
# 2.63275734546653e-09
# 1.9378976572553317

# %%
def train_model_on(dataset, subset, device, tol = 1e-3, source_trained=False):
    loader = iter(InfiniteDataLoader(dataset,  
                                weights=None,
                                batch_size=config.train.train_bs,
                                num_workers=config.num_workers, 
                                subset=subset))

    if source_trained:
        model = copy.deepcopy(alg.model.cpu()).to(device)
        display('source_trained')
    else:
        encoder = register.models[config.model.name](config)
        model = nn.Sequential(encoder, 
                              nn.Linear(encoder.n_outputs, config.dataset.num_classes)).to(device)
    model.train()
    # model.eval()
    # display('model.eval()')
    optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
    lowest_loss = float('inf')
    stop_count = 0
    epoch_pbar = tqdm(range(100))
    for epoch in epoch_pbar:
        mean_loss = []
        for _ in range(100):
            # display(f'{i}')
            data, target = next(loader)
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = config.metric.loss_func(output, target)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            mean_loss.append(loss.item())
        mean_loss = np.mean(mean_loss)
        epoch_pbar.set_description(f'ML: {mean_loss:.6f}')

        stop_count += 1
        if mean_loss < lowest_loss:
            stop_count = 0
            lowest_loss = mean_loss
        if stop_count >= 5 or mean_loss < tol:
            break
    return model

@torch.no_grad()
def test_on_env(model, loader, device):
    model.eval()
    test_loss = 0
    test_acc = 0
    for data, target in loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        test_loss += config.metric.loss_func(output, target, reduction='sum').item()
        test_acc += config.metric.score_func(target, output) * len(data)
    test_loss /= len(loader.sampler)
    test_acc /= len(loader.sampler)
    return test_loss, test_acc

# %%
Full_D_S_loader = FastDataLoader(D_S,  
                            weights=None,
                            batch_size=config.train.train_bs,
                            num_workers=config.num_workers)
Full_D_T_loader = FastDataLoader(D_T,  
                            weights=None,
                            batch_size=config.train.train_bs,
                            num_workers=config.num_workers)

# %%
source_like_model = train_model_on(D_T, np.random.choice(len(argent), 2000, replace=False), device, tol=1e-4)
# target_like_model = train_model_on(D_T, np.random.choice(argent[-2000:], 300, replace=False), device, tol=1e-4)
result_df = pd.DataFrame(index=['Model'], columns=['D_S', 'D_T'], dtype=float)
test_idx = 0
result_df.loc['Model', 'D_T'] = test_on_env(source_like_model, Full_D_T_loader, device=device)[test_idx]
result_df.loc['Model', 'D_S'] = test_on_env(source_like_model, Full_D_S_loader, device=device)[test_idx]
display(result_df)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#             D_S       D_T
# Model  0.950454  0.214905

# %%
source_like_model = train_model_on(D_T, argent[:2000], device, tol=1e-4, source_trained=False)
target_like_model = train_model_on(D_T, argent[-2000:], device, tol=1e-4, source_trained=False)
result_f_df = pd.DataFrame(index=['Model_S_like', 'Model_T_like'], columns=['D_S', 'D_T'], dtype=float)
test_idx = 0
result_f_df.loc['Model_S_like', 'D_T'] = test_on_env(source_like_model, Full_D_T_loader, device=device)[test_idx]
result_f_df.loc['Model_S_like', 'D_S'] = test_on_env(source_like_model, Full_D_S_loader, device=device)[test_idx]
result_f_df.loc['Model_T_like', 'D_T'] = test_on_env(target_like_model, Full_D_T_loader, device=device)[test_idx]
result_f_df.loc['Model_T_like', 'D_S'] = test_on_env(target_like_model, Full_D_S_loader, device=device)[test_idx]
display(result_f_df)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#                    D_S       D_T
# Model_S_like  0.564108  0.802188
# Model_T_like  2.511737  0.341390

# %%
# Out:
#                    D_S       D_T
# Model_S_like  0.813965  0.756515
# Model_T_like  0.514160  0.916278

# %%
source_like_model = train_model_on(D_T, argent[:300], device, tol=1e-4, source_trained=True)
target_like_model = train_model_on(D_T, argent[-300:], device, tol=1e-4, source_trained=True)
result_df = pd.DataFrame(index=['Model_S_like', 'Model_T_like'], columns=['D_S', 'D_T'], dtype=float)
test_idx = 0
result_df.loc['Model_S_like', 'D_T'] = test_on_env(source_like_model, Full_D_T_loader, device=device)[test_idx]
result_df.loc['Model_S_like', 'D_S'] = test_on_env(source_like_model, Full_D_S_loader, device=device)[test_idx]
result_df.loc['Model_T_like', 'D_T'] = test_on_env(target_like_model, Full_D_T_loader, device=device)[test_idx]
result_df.loc['Model_T_like', 'D_S'] = test_on_env(target_like_model, Full_D_S_loader, device=device)[test_idx]
display(result_df)
# Out:
# 'source_trained'
#   0%|          | 0/100 [00:00<?, ?it/s]
# 'source_trained'
#   0%|          | 0/100 [00:00<?, ?it/s]
#                    D_S       D_T
# Model_S_like  0.061888  1.883793
# Model_T_like  0.853899  0.772455

# %%
source_like_model = train_model_on(D_T, np.concatenate([argent[:2000], argent[-300:]]), device, tol=1e-3, source_trained=True)
target_like_model = train_model_on(D_T, np.concatenate([argent[:300], argent[-2000:]]), device, tol=1e-3, source_trained=True)
result_df = pd.DataFrame(index=['Model_S_like', 'Model_T_like'], columns=['D_S', 'D_T'], dtype=float)
test_idx = 0
result_df.loc['Model_S_like', 'D_T'] = test_on_env(source_like_model, Full_D_T_loader, device=device)[test_idx]
result_df.loc['Model_S_like', 'D_S'] = test_on_env(source_like_model, Full_D_S_loader, device=device)[test_idx]
result_df.loc['Model_T_like', 'D_T'] = test_on_env(target_like_model, Full_D_T_loader, device=device)[test_idx]
result_df.loc['Model_T_like', 'D_S'] = test_on_env(target_like_model, Full_D_S_loader, device=device)[test_idx]
display(result_df)
# Out:
# 'source_trained'
#   0%|          | 0/100 [00:00<?, ?it/s]
# 'source_trained'
#   0%|          | 0/100 [00:00<?, ?it/s]
#                    D_S       D_T
# Model_S_like  0.136056  0.459091
# Model_T_like  0.356054  0.200455

# %%
df = pd.DataFrame(index=['Current domain', *(i for i in range(4)), 'Frame AVG'], columns=[*(i for i in range(4)), 'Test AVG'], dtype=float)

# %%
df.loc[0, 0] = 3.9898989898893748

# %%
df.round(4)
# Out:
#                      0   1   2   3  Test AVG
# Current domain     NaN NaN NaN NaN       NaN
# 0               3.9899 NaN NaN NaN       NaN
# 1                  NaN NaN NaN NaN       NaN
# 2                  NaN NaN NaN NaN       NaN
# 3                  NaN NaN NaN NaN       NaN
# Frame AVG          NaN NaN NaN NaN       NaN

# %%
# Out:
#                        task  random_seed  exp_round log_file  gpu_idx  \
# weight_decay          train          110          1  default        6
# save_gap              train          110          1  default        6
# tr_ctn                train          110          1  default        6
# epoch                 train          110          1  default        6
# ctn_epoch             train          110          1  default        6
# alpha                 train          110          1  default        6
# stage_stones          train          110          1  default        6
# pre_train             train          110          1  default        6
# lr                    train          110          1  default        6
# mile_stones           train          110          1  default        6
# gamma                 train          110          1  default        6
# log_interval          train          110          1  default        6
# train_bs              train          110          1  default        6
# val_bs                train          110          1  default        6
# test_bs               train          110          1  default        6
# max_iters             train          110          1  default        6
# max_epoch             train          110          1  default        6
# num_steps             train          110          1  default        6
# dim_hidden            train          110          1  default        6
# dim_ffn               train          110          1  default        6
# dropout_rate          train          110          1  default        6
# model_layer           train          110          1  default        6
# global_pool           train          110          1  default        6
# name                  train          110          1  default        6
# resnet18              train          110          1  default        6
# freeze_bn             train          110          1  default        6
# model_level           train          110          1  default        6
# nonlinear_classifier  train          110          1  default        6
# dataloader_name       train          110          1  default        6
# dataset_root          train          110          1  default        6
# generate              train          110          1  default        6
# dim_node              train          110          1  default        6
# dim_edge              train          110          1  default        6
# num_classes           train          110          1  default        6
# num_envs              train          110          1  default        6
# feat_dims             train          110          1  default        6
# edge_feat_dims        train          110          1  default        6
# data_augmentation     train          110          1  default        6
# test_envs             train          110          1  default        6
# shift_type            train          110          1  default        6
# domain                train          110          1  default        6
# dataset_type          train          110          1  default        6
# class_balanced        train          110          1  default        6
# num_domains           train          110          1  default        6
# input_shape           train          110          1  default        6
# extra_param           train          110          1  default        6
# alg                   train          110          1  default        6
# ood_param             train          110          1  default        6
# batch_size            train          110          1  default        6
# budgets               train          110          1  default        6
# episodic              train          110          1  default        6
# SimATTA             train          110          1  default        6
# Tent                  train          110          1  default        6
# TAL                   train          110          1  default        6
# SAR                   train          110          1  default        6
# EATA                  train          110          1  default        6
# TICP                  train          110          1  default        6
#
#                                                               ckpt_root  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
#
#                                                                ckpt_dir  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
#
#                      save_tag other_saved  clean_save  ...  \
# weight_decay             None        None       False  ...
# save_gap                 None        None       False  ...
# tr_ctn                   None        None       False  ...
# epoch                    None        None       False  ...
# ctn_epoch                None        None       False  ...
# alpha                    None        None       False  ...
# stage_stones             None        None       False  ...
# pre_train                None        None       False  ...
# lr                       None        None       False  ...
# mile_stones              None        None       False  ...
# gamma                    None        None       False  ...
# log_interval             None        None       False  ...
# train_bs                 None        None       False  ...
# val_bs                   None        None       False  ...
# test_bs                  None        None       False  ...
# max_iters                None        None       False  ...
# max_epoch                None        None       False  ...
# num_steps                None        None       False  ...
# dim_hidden               None        None       False  ...
# dim_ffn                  None        None       False  ...
# dropout_rate             None        None       False  ...
# model_layer              None        None       False  ...
# global_pool              None        None       False  ...
# name                     None        None       False  ...
# resnet18                 None        None       False  ...
# freeze_bn                None        None       False  ...
# model_level              None        None       False  ...
# nonlinear_classifier     None        None       False  ...
# dataloader_name          None        None       False  ...
# dataset_root             None        None       False  ...
# generate                 None        None       False  ...
# dim_node                 None        None       False  ...
# dim_edge                 None        None       False  ...
# num_classes              None        None       False  ...
# num_envs                 None        None       False  ...
# feat_dims                None        None       False  ...
# edge_feat_dims           None        None       False  ...
# data_augmentation        None        None       False  ...
# test_envs                None        None       False  ...
# shift_type               None        None       False  ...
# domain                   None        None       False  ...
# dataset_type             None        None       False  ...
# class_balanced           None        None       False  ...
# num_domains              None        None       False  ...
# input_shape              None        None       False  ...
# extra_param              None        None       False  ...
# alg                      None        None       False  ...
# ood_param                None        None       False  ...
# batch_size               None        None       False  ...
# budgets                  None        None       False  ...
# episodic                 None        None       False  ...
# SimATTA                None        None       False  ...
# Tent                     None        None       False  ...
# TAL                      None        None       False  ...
# SAR                      None        None       False  ...
# EATA                     None        None       False  ...
# TICP                     None        None       False  ...
#
#                                                                    atta  \
# weight_decay                                                        NaN
# save_gap                                                            NaN
# tr_ctn                                                              NaN
# epoch                                                               NaN
# ctn_epoch                                                           NaN
# alpha                                                               NaN
# stage_stones                                                        NaN
# pre_train                                                           NaN
# lr                                                                  NaN
# mile_stones                                                         NaN
# gamma                                                               NaN
# log_interval                                                        NaN
# train_bs                                                            NaN
# val_bs                                                              NaN
# test_bs                                                             NaN
# max_iters                                                           NaN
# max_epoch                                                           NaN
# num_steps                                                           NaN
# dim_hidden                                                          NaN
# dim_ffn                                                             NaN
# dropout_rate                                                        NaN
# model_layer                                                         NaN
# global_pool                                                         NaN
# name                                                            AlgBase
# resnet18                                                            NaN
# freeze_bn                                                           NaN
# model_level                                                         NaN
# nonlinear_classifier                                                NaN
# dataloader_name                                                     NaN
# dataset_root                                                        NaN
# generate                                                            NaN
# dim_node                                                            NaN
# dim_edge                                                            NaN
# num_classes                                                         NaN
# num_envs                                                            NaN
# feat_dims                                                           NaN
# edge_feat_dims                                                      NaN
# data_augmentation                                                   NaN
# test_envs                                                           NaN
# shift_type                                                          NaN
# domain                                                              NaN
# dataset_type                                                        NaN
# class_balanced                                                      NaN
# num_domains                                                         NaN
# input_shape                                                         NaN
# extra_param                                                         NaN
# alg                                                                 NaN
# ood_param                                                           NaN
# batch_size                                                           16
# budgets                                                            None
# episodic                                                           None
# SimATTA             {'steps': None, 'lr': None, 'eh': None, 'el': ...
# Tent                                        {'steps': None, 'lr': None}
# TAL                             {'steps': None, 'lr': None, 'e0': None}
# SAR                   {'steps': None, 'reset_constant_em': None, 'lr...
# EATA                  {'steps': None, 'lr': None, 'd_margin': None, ...
# TICP                                                                NaN
#
#                                                             config_path  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/configs...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/configs...
#
#                                                               test_ckpt  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
#
#                                                            id_test_ckpt  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
#
#                      full_clean  \
# weight_decay               None
# save_gap                   None
# tr_ctn                     None
# epoch                      None
# ctn_epoch                  None
# alpha                      None
# stage_stones               None
# pre_train                  None
# lr                         None
# mile_stones                None
# gamma                      None
# log_interval               None
# train_bs                   None
# val_bs                     None
# test_bs                    None
# max_iters                  None
# max_epoch                  None
# num_steps                  None
# dim_hidden                 None
# dim_ffn                    None
# dropout_rate               None
# model_layer                None
# global_pool                None
# name                       None
# resnet18                   None
# freeze_bn                  None
# model_level                None
# nonlinear_classifier       None
# dataloader_name            None
# dataset_root               None
# generate                   None
# dim_node                   None
# dim_edge                   None
# num_classes                None
# num_envs                   None
# feat_dims                  None
# edge_feat_dims             None
# data_augmentation          None
# test_envs                  None
# shift_type                 None
# domain                     None
# dataset_type               None
# class_balanced             None
# num_domains                None
# input_shape                None
# extra_param                None
# alg                        None
# ood_param                  None
# batch_size                 None
# budgets                    None
# episodic                   None
# SimATTA                  None
# Tent                       None
# TAL                        None
# SAR                        None
# EATA                       None
# TICP                       None
#
#                                                                log_path  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
#
#                                                      tensorboard_logdir  \
# weight_decay          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# save_gap              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# tr_ctn                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# epoch                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ctn_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alpha                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# stage_stones          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# pre_train             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# lr                    /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# mile_stones           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# gamma                 /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# log_interval          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# train_bs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# val_bs                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_bs               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_iters             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# max_epoch             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_steps             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_hidden            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_ffn               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dropout_rate          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_layer           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# global_pool           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# name                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# resnet18              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# freeze_bn             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# model_level           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# nonlinear_classifier  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataloader_name       /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_root          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# generate              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_node              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dim_edge              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_classes           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_envs              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# feat_dims             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# edge_feat_dims        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# data_augmentation     /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# test_envs             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# shift_type            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# domain                /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# dataset_type          /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# class_balanced        /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# num_domains           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# input_shape           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# extra_param           /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# alg                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# ood_param             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# batch_size            /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# budgets               /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# episodic              /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SimATTA             /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# Tent                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TAL                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# SAR                   /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# EATA                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
# TICP                  /data/shurui.gui/Projects/TTA/GraphTTA/storage...
#
#                                                                     tta  \
# weight_decay                                                        NaN
# save_gap                                                            NaN
# tr_ctn                                                              NaN
# epoch                                                               NaN
# ctn_epoch                                                           NaN
# alpha                                                               NaN
# stage_stones                                                        NaN
# pre_train                                                           NaN
# lr                                                                  NaN
# mile_stones                                                         NaN
# gamma                                                               NaN
# log_interval                                                        NaN
# train_bs                                                            NaN
# val_bs                                                              NaN
# test_bs                                                             NaN
# max_iters                                                           NaN
# max_epoch                                                           NaN
# num_steps                                                           NaN
# dim_hidden                                                          NaN
# dim_ffn                                                             NaN
# dropout_rate                                                        NaN
# model_layer                                                         NaN
# global_pool                                                         NaN
# name                                                               None
# resnet18                                                            NaN
# freeze_bn                                                           NaN
# model_level                                                         NaN
# nonlinear_classifier                                                NaN
# dataloader_name                                                     NaN
# dataset_root                                                        NaN
# generate                                                            NaN
# dim_node                                                            NaN
# dim_edge                                                            NaN
# num_classes                                                         NaN
# num_envs                                                            NaN
# feat_dims                                                           NaN
# edge_feat_dims                                                      NaN
# data_augmentation                                                   NaN
# test_envs                                                           NaN
# shift_type                                                          NaN
# domain                                                              NaN
# dataset_type                                                        NaN
# class_balanced                                                      NaN
# num_domains                                                         NaN
# input_shape                                                         NaN
# extra_param                                                         NaN
# alg                                                                 NaN
# ood_param                                                           NaN
# batch_size                                                          NaN
# budgets                                                             NaN
# episodic                                                           None
# SimATTA                                                           NaN
# Tent                                        {'steps': None, 'lr': None}
# TAL                                                                 NaN
# SAR                   {'steps': None, 'reset_constant_em': None, 'lr...
# EATA                                                                NaN
# TICP                  {'num_drops': None, 'classifier_epochs': None,...
#
#                       device  \
# weight_decay          cuda:6
# save_gap              cuda:6
# tr_ctn                cuda:6
# epoch                 cuda:6
# ctn_epoch             cuda:6
# alpha                 cuda:6
# stage_stones          cuda:6
# pre_train             cuda:6
# lr                    cuda:6
# mile_stones           cuda:6
# gamma                 cuda:6
# log_interval          cuda:6
# train_bs              cuda:6
# val_bs                cuda:6
# test_bs               cuda:6
# max_iters             cuda:6
# max_epoch             cuda:6
# num_steps             cuda:6
# dim_hidden            cuda:6
# dim_ffn               cuda:6
# dropout_rate          cuda:6
# model_layer           cuda:6
# global_pool           cuda:6
# name                  cuda:6
# resnet18              cuda:6
# freeze_bn             cuda:6
# model_level           cuda:6
# nonlinear_classifier  cuda:6
# dataloader_name       cuda:6
# dataset_root          cuda:6
# generate              cuda:6
# dim_node              cuda:6
# dim_edge              cuda:6
# num_classes           cuda:6
# num_envs              cuda:6
# feat_dims             cuda:6
# edge_feat_dims        cuda:6
# data_augmentation     cuda:6
# test_envs             cuda:6
# shift_type            cuda:6
# domain                cuda:6
# dataset_type          cuda:6
# class_balanced        cuda:6
# num_domains           cuda:6
# input_shape           cuda:6
# extra_param           cuda:6
# alg                   cuda:6
# ood_param             cuda:6
# batch_size            cuda:6
# budgets               cuda:6
# episodic              cuda:6
# SimATTA             cuda:6
# Tent                  cuda:6
# TAL                   cuda:6
# SAR                   cuda:6
# EATA                  cuda:6
# TICP                  cuda:6
#
#                                                                  metric
# weight_decay          <GTTA.utils.metric.Metric object at 0x7f813038...
# save_gap              <GTTA.utils.metric.Metric object at 0x7f813038...
# tr_ctn                <GTTA.utils.metric.Metric object at 0x7f813038...
# epoch                 <GTTA.utils.metric.Metric object at 0x7f813038...
# ctn_epoch             <GTTA.utils.metric.Metric object at 0x7f813038...
# alpha                 <GTTA.utils.metric.Metric object at 0x7f813038...
# stage_stones          <GTTA.utils.metric.Metric object at 0x7f813038...
# pre_train             <GTTA.utils.metric.Metric object at 0x7f813038...
# lr                    <GTTA.utils.metric.Metric object at 0x7f813038...
# mile_stones           <GTTA.utils.metric.Metric object at 0x7f813038...
# gamma                 <GTTA.utils.metric.Metric object at 0x7f813038...
# log_interval          <GTTA.utils.metric.Metric object at 0x7f813038...
# train_bs              <GTTA.utils.metric.Metric object at 0x7f813038...
# val_bs                <GTTA.utils.metric.Metric object at 0x7f813038...
# test_bs               <GTTA.utils.metric.Metric object at 0x7f813038...
# max_iters             <GTTA.utils.metric.Metric object at 0x7f813038...
# max_epoch             <GTTA.utils.metric.Metric object at 0x7f813038...
# num_steps             <GTTA.utils.metric.Metric object at 0x7f813038...
# dim_hidden            <GTTA.utils.metric.Metric object at 0x7f813038...
# dim_ffn               <GTTA.utils.metric.Metric object at 0x7f813038...
# dropout_rate          <GTTA.utils.metric.Metric object at 0x7f813038...
# model_layer           <GTTA.utils.metric.Metric object at 0x7f813038...
# global_pool           <GTTA.utils.metric.Metric object at 0x7f813038...
# name                  <GTTA.utils.metric.Metric object at 0x7f813038...
# resnet18              <GTTA.utils.metric.Metric object at 0x7f813038...
# freeze_bn             <GTTA.utils.metric.Metric object at 0x7f813038...
# model_level           <GTTA.utils.metric.Metric object at 0x7f813038...
# nonlinear_classifier  <GTTA.utils.metric.Metric object at 0x7f813038...
# dataloader_name       <GTTA.utils.metric.Metric object at 0x7f813038...
# dataset_root          <GTTA.utils.metric.Metric object at 0x7f813038...
# generate              <GTTA.utils.metric.Metric object at 0x7f813038...
# dim_node              <GTTA.utils.metric.Metric object at 0x7f813038...
# dim_edge              <GTTA.utils.metric.Metric object at 0x7f813038...
# num_classes           <GTTA.utils.metric.Metric object at 0x7f813038...
# num_envs              <GTTA.utils.metric.Metric object at 0x7f813038...
# feat_dims             <GTTA.utils.metric.Metric object at 0x7f813038...
# edge_feat_dims        <GTTA.utils.metric.Metric object at 0x7f813038...
# data_augmentation     <GTTA.utils.metric.Metric object at 0x7f813038...
# test_envs             <GTTA.utils.metric.Metric object at 0x7f813038...
# shift_type            <GTTA.utils.metric.Metric object at 0x7f813038...
# domain                <GTTA.utils.metric.Metric object at 0x7f813038...
# dataset_type          <GTTA.utils.metric.Metric object at 0x7f813038...
# class_balanced        <GTTA.utils.metric.Metric object at 0x7f813038...
# num_domains           <GTTA.utils.metric.Metric object at 0x7f813038...
# input_shape           <GTTA.utils.metric.Metric object at 0x7f813038...
# extra_param           <GTTA.utils.metric.Metric object at 0x7f813038...
# alg                   <GTTA.utils.metric.Metric object at 0x7f813038...
# ood_param             <GTTA.utils.metric.Metric object at 0x7f813038...
# batch_size            <GTTA.utils.metric.Metric object at 0x7f813038...
# budgets               <GTTA.utils.metric.Metric object at 0x7f813038...
# episodic              <GTTA.utils.metric.Metric object at 0x7f813038...
# SimATTA             <GTTA.utils.metric.Metric object at 0x7f813038...
# Tent                  <GTTA.utils.metric.Metric object at 0x7f813038...
# TAL                   <GTTA.utils.metric.Metric object at 0x7f813038...
# SAR                   <GTTA.utils.metric.Metric object at 0x7f813038...
# EATA                  <GTTA.utils.metric.Metric object at 0x7f813038...
# TICP                  <GTTA.utils.metric.Metric object at 0x7f813038...
#
# [57 rows x 27 columns]
